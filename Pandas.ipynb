# %%
# csv - comma seperated values
# pandas - data manipulation package
# data frame - pandas ma bhayeko datatype jasle 2d tabular data lai store garxa

# %%
import pandas as pd

# %%
file = open("info.csv",'x')
file.close()

# %%
info = str()
file = open("info.csv",'w')
n = int(input("enter the value of n="))
for i in range(n):
    name = input("enter name = ")
    age = int(input("enter age = "))
    add = input("enter address = ")
    info = info + f"{name},{age},{add}\n"
file.write(info)
file.close()
# Out:
# enter the value of n= 6
# enter name =  ram
# enter age =  34
# enter address =  ktm
# enter name =  shyam
# enter age =  45
# enter address =  bkt
# enter name =  pujya
# enter age =  17
# enter address =  llt
# enter name =  pukar
# enter age =  24
# enter address =  slyth
# enter name =  aarati
# enter age =  23
# enter address =  sisneri
# enter name =  pooja
# enter age =  26
# enter address =  dakshindhoka

# %%
import pandas as pd
df = pd.read_csv('info.csv')
df
# Out:
#       ram  34           ktm
# 0   shyam  45           bkt
# 1   pujya  17           llt
# 2   pukar  24         slyth
# 3  aarati  23       sisneri
# 4   pooja  26  dakshindhoka

# %%
info = str()
file = open("info.csv",'w')
file.write('name,age,address\n')
n = int(input("enter the value of n="))
for i in range(n):
    name = input("enter name = ")
    age = int(input("enter age = "))
    add = input("enter address = ")
    info = info + f"{name},{age},{add}\n"
    
file.write(info)
file.close()
# Out:
# enter the value of n= 6
# enter name =  ram
# enter age =  45
# enter address =  ktm
# enter name =  shyam
# enter age =  56
# enter address =  bkt
# enter name =  pujya
# enter age =  51
# enter address =  lalitpur
# enter name =  pukar
# enter age =  23
# enter address =  kirtipur
# enter name =  hari
# enter age =  89
# enter address =  heaven
# enter name =  gopal
# enter age =  10
# enter address =  ktm

# %%
import pandas as pd
df = pd.read_csv('info.csv')
df
# Out:
#     name  age   address
# 0    ram   45       ktm
# 1  shyam   56       bkt
# 2  pujya   51  lalitpur
# 3  pukar   23  kirtipur
# 4   hari   89    heaven
# 5  gopal   10       ktm

# %%
df = pd.read_csv('info.csv',nrows = 5)
df
# Out:
#     name  age   address
# 0    ram   45       ktm
# 1  shyam   56       bkt
# 2  pujya   51  lalitpur
# 3  pukar   23  kirtipur
# 4   hari   89    heaven

# %%
df = pd.read_csv('info.csv')
df.head()
# Out:
#     name  age   address
# 0    ram   45       ktm
# 1  shyam   56       bkt
# 2  pujya   51  lalitpur
# 3  pukar   23  kirtipur
# 4   hari   89    heaven

# %%
df = pd.read_csv('info.csv')
df.tail()
# Out:
#     name  age   address
# 1  shyam   56       bkt
# 2  pujya   51  lalitpur
# 3  pukar   23  kirtipur
# 4   hari   89    heaven
# 5  gopal   10       ktm

# %%
df = pd.read_csv('info.csv',usecols = ['name','age'])
df
# Out:
#     name  age
# 0    ram   45
# 1  shyam   56
# 2  pujya   51
# 3  pukar   23
# 4   hari   89
# 5  gopal   10

# %%
df = pd.read_csv('info.csv',usecols = ['name','address'])
df
# Out:
#     name   address
# 0    ram       ktm
# 1  shyam       bkt
# 2  pujya  lalitpur
# 3  pukar  kirtipur
# 4   hari    heaven
# 5  gopal       ktm

# %%
df = pd.read_csv('info.csv')
df
# Out:
#     name  age   address
# 0    ram   45       ktm
# 1  shyam   56       bkt
# 2  pujya   51  lalitpur
# 3  pukar   23  kirtipur
# 4   hari   89    heaven
# 5  gopal   10       ktm

# %%
df.iloc[1:5]
# Out:
#     name  age   address
# 1  shyam   56       bkt
# 2  pujya   51  lalitpur
# 3  pukar   23  kirtipur
# 4   hari   89    heaven

# %%
df['address']
# Out:
# 0         ktm
# 1         bkt
# 2    lalitpur
# 3    kirtipur
# 4      heaven
# 5         ktm
# Name: address, dtype: object

# %%
df['address'] == 'ktm'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# Name: address, dtype: bool

# %%
df[df['address'] == 'ktm']
# Out:
#     name  age address
# 0    ram   45     ktm
# 5  gopal   10     ktm

# %%
df[(df['address'] == 'ktm' ) & (df['age'] >=17)]
# Out:
#   name  age address
# 0  ram   45     ktm

# %%
# & for and 
# | for or

# %%
df = pd.read_csv('info.csv')
df['sn'] = [i for i in range(1,7)]
df
# Out:
#     name  age   address  sn
# 0    ram   45       ktm   1
# 1  shyam   56       bkt   2
# 2  pujya   51  lalitpur   3
# 3  pukar   23  kirtipur   4
# 4   hari   89    heaven   5
# 5  gopal   10       ktm   6

# %%
 # loc bhaneko localizer ho ani iloc bhaneko index localizer ho

# %%
data = {'name':['akash','ayush'],'age':[22,55],'address':['lalitpur','hariharbhawan'],'sn':[7,8]}
data
# Out:
# {'name': ['akash', 'ayush'],
#  'age': [22, 55],
#  'address': ['lalitpur', 'hariharbhawan'],
#  'sn': [7, 8]}

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#     name  age        address  sn
# 0  akash   22       lalitpur   7
# 1  ayush   55  hariharbhawan   8

# %%
df = pd.read_csv('info.csv')
df['sn'] = [i for i in range(1,7)]
df
# Out:
#     name  age   address  sn
# 0    ram   45       ktm   1
# 1  shyam   56       bkt   2
# 2  pujya   51  lalitpur   3
# 3  pukar   23  kirtipur   4
# 4   hari   89    heaven   5
# 5  gopal   10       ktm   6

# %%
df = pd.concat([df,df1])
df
# Out:
#     name  age        address  sn
# 0    ram   45            ktm   1
# 1  shyam   56            bkt   2
# 2  pujya   51       lalitpur   3
# 3  pukar   23       kirtipur   4
# 4   hari   89         heaven   5
# 5  gopal   10            ktm   6
# 0  akash   22       lalitpur   7
# 1  ayush   55  hariharbhawan   8

# %%
df.to_csv('new_data.csv')

# %%
df = pd.read_csv('new_data.csv')
df
# Out:
#    Unnamed: 0   name  age        address  sn
# 0           0    ram   45            ktm   1
# 1           1  shyam   56            bkt   2
# 2           2  pujya   51       lalitpur   3
# 3           3  pukar   23       kirtipur   4
# 4           4   hari   89         heaven   5
# 5           5  gopal   10            ktm   6
# 6           0  akash   22       lalitpur   7
# 7           1  ayush   55  hariharbhawan   8

# %%
df = pd.read_csv('new_data.csv',usecols = ['name','age','address','sn'])
df
# Out:
#     name  age        address  sn
# 0    ram   45            ktm   1
# 1  shyam   56            bkt   2
# 2  pujya   51       lalitpur   3
# 3  pukar   23       kirtipur   4
# 4   hari   89         heaven   5
# 5  gopal   10            ktm   6
# 6  akash   22       lalitpur   7
# 7  ayush   55  hariharbhawan   8

# %%
df = pd.read_csv('new_data.csv',usecols = ['name','age','address','sn'],index_col = 'sn')
df
# Out:
#      name  age        address
# sn
# 1     ram   45            ktm
# 2   shyam   56            bkt
# 3   pujya   51       lalitpur
# 4   pukar   23       kirtipur
# 5    hari   89         heaven
# 6   gopal   10            ktm
# 7   akash   22       lalitpur
# 8   ayush   55  hariharbhawan

# %%
df.drop([3,4],axis = 0)
# Out:
#      name  age        address
# sn
# 1     ram   45            ktm
# 2   shyam   56            bkt
# 5    hari   89         heaven
# 6   gopal   10            ktm
# 7   akash   22       lalitpur
# 8   ayush   55  hariharbhawan

# %%
df.drop(['age'],axis = 1)
# Out:
#      name        address
# sn
# 1     ram            ktm
# 2   shyam            bkt
# 3   pujya       lalitpur
# 4   pukar       kirtipur
# 5    hari         heaven
# 6   gopal            ktm
# 7   akash       lalitpur
# 8   ayush  hariharbhawan
